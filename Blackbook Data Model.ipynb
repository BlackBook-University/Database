# %%
import numpy as np
import pandas as pd
import matplotlib
import csv

# %%
database = pd.read_csv("CourseRetSuccessSumm.csv")

# %%
database
# Out:
#               Unnamed: 0                      Unnamed: 1 Unnamed: 2  \
# 0                    NaN                             NaN        NaN
# 1             State Name       Course Instruction Method     Gender
# 2    State of California  Non Distance Education Methods     Female
# 3    State of California  Non Distance Education Methods     Female
# 4    State of California  Non Distance Education Methods     Female
# ..                   ...                             ...        ...
# 264  State of California  Non Distance Education Methods    Unknown
# 265  State of California  Non Distance Education Methods    Unknown
# 266  State of California  Non Distance Education Methods    Unknown
# 267  State of California  Non Distance Education Methods    Unknown
# 268  State of California  Non Distance Education Methods    Unknown
#
#     Unnamed: 3                      Unnamed: 4         Fall 2010  \
# 0          NaN                             NaN      Basic Skills
# ...
